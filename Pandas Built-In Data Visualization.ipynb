# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('C:\\Users\\Vivek\\Desktop\\Great Learning\\PGP-DSE\\Python\\Udemy Courses\\Python for Data Science & Machine Learning\\Refactored_Py_DS_ML_Bootcamp-master\\07-Pandas-Built-in-Data-Viz\\df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('C:\\Users\\Vivek\\Desktop\\Great Learning\\PGP-DSE\\Python\\Udemy Courses\\Python for Data Science & Machine Learning\\Refactored_Py_DS_ML_Bootcamp-master\\07-Pandas-Built-in-Data-Viz\\df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# #### Histogram

# %%
df1['A'].hist(bins=30)

# %%
# 2nd way of plotting a histogram of a DataFrame column
df1['A'].plot(kind='hist',bins=30)

# %%
# 2nd way of plotting a histogram of a DataFrame column
df1['A'].plot.hist()

# %% [markdown]
# #### Area Plot

# %%
df2.plot.area(alpha=0.4)

# %% [markdown]
# #### Bar Plot

# %%
df2.plot.bar()

# %% [markdown]
# It takes each index as a category and plot the values of 4 columns i.e., a, b, c and d as bars.

# %%
# If you want to stack the columns above one another, you can use argument stacked=True

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# #### Line Plot

# %%
df1.plot.line(y='B')

# %%
df1.plot.line(y='B',figsize=(12,3))

# %% [markdown]
# #### Scatter Plot

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### Box Plot

# %%
df1.plot.box()

# %%
new_df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
new_df.head()
# Out:
#           a         b
# 0 -0.316115 -0.628021
# 1 -0.501397  1.060258
# 2 -0.465935 -0.449482
# 3 -0.053007  0.847547
# 4 -0.766496  1.446754

# %%
new_df.plot.hexbin(x='a',y='b',gridsize=25)

# %% [markdown]
# #### KDE Plot

# %%
df2['a'].plot.kde()

# %%
df2.plot.density() # It will take all columns of DF
